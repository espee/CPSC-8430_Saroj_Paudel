# %%
import matplotlib.pyplot as plt
import pandas as pd

is_score = []
for file in ['IS_dcgan.csv', 'IS_wgan.csv', 'IS_acgan.csv']:
    is_score.append(pd.read_csv(file))
    
plt.plot(data[0]['epoch'], is_score[0][' IS '], label="DCGAN")
plt.plot(data[1]['epoch'], is_score[1][' IS '], label="WGAN")
plt.plot(data[2]['epoch'], is_score[2][' IS '], label="ACGAN")

plt.xlabel("Epoch")
plt.ylabel("Inception Score")
plt.legend()
plt.savefig("Inception_score_comparison.png")
print("Image Inception_score_comparison.png exported!")
# Out:
# Image Inception_score_comparison.png exported!
